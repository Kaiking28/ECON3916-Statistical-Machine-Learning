# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiking28/ECON3916-Statistical-Machine-Learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lab 1

import pandas as pd
import numpy as np

Data = {
    'country':['united states','argentina','australia','brazil'],
    'country':['united states','argentina','australia','brazil']
    }

  df = pd.DataFrame(data)
  print(df)
